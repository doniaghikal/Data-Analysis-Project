# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
cmap = plt.get_cmap('tab20')
colors = [cmap(i) for i in range(20)]

# %%
# !pip install pyodbc
import pyodbc
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\dg038\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
connection=pyodbc.connect(
    "Driver={SQL Server};"
    "Server=doniaa\SQLEXPRESS;"
    "Database=shopping;"
    "UID=sa;"
    "PWD=1248;"
)
query=" SELECT * FROM dbo.shopping_trends"
df=pd.read_sql(query,connection)
# Out:
# C:\Users\dg038\AppData\Local\Temp\ipykernel_14500\2451557179.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,connection)

# %%
df
# Out:
#       Customer_ID  Age  Gender Item_Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase_Amount_USD       Location Size      Color  Season  \
# 0                      53       Kentucky    L       Gray  Winter
# 1                      64          Maine    L     Maroon  Winter
# ...

# %%
df.head()
# Out:
#    Customer_ID  Age Gender Item_Purchased  Category  Purchase_Amount_USD  \
# 0            1   55   Male         Blouse  Clothing                   53
# 1            2   19   Male        Sweater  Clothing                   64
# 2            3   50   Male          Jeans  Clothing                   73
# 3            4   21   Male        Sandals  Footwear                   90
# 4            5   45   Male         Blouse  Clothing                   49
#
#         Location Size      Color  Season  Review_Rating Subscription_Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#   Payment_Method  Shipping_Type Discount_Applied Promo_Code_Used  \
# ...

# %%
df.tail()
# Out:
#       Customer_ID  Age  Gender Item_Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase_Amount_USD    Location Size      Color  Season  Review_Rating  \
# 3895                   28    Virginia    L  Turquoise  Summer            4.2
# 3896                   49        Iowa    L      White  Spring            4.5
# 3897                   33  New Jersey    L      Green  Spring            2.9
# 3898                   77   Minnesota    S      Brown  Summer            3.8
# 3899                   81  California    M      Beige  Spring            3.1
#
#      Subscription_Status Payment_Method   Shipping_Type Discount_Applied  \
# ...

# %% [markdown]
# 0

# %%
df.sample(10)
# Out:
#       Customer_ID  Age  Gender Item_Purchased     Category  \
# 1211         1212   23    Male         Hoodie     Clothing
# 350           351   42    Male        Sweater     Clothing
# 2845         2846   26  Female       Backpack  Accessories
# 3336         3337   39  Female         Blouse     Clothing
# 3087         3088   62  Female          Shirt     Clothing
# 183           184   58    Male          Skirt     Clothing
# 3827         3828   62  Female        Jewelry  Accessories
# 444           445   48    Male          Dress     Clothing
# 26             27   38    Male        Jewelry  Accessories
# 2823         2824   26  Female          Dress     Clothing
#
#       Purchase_Amount_USD        Location Size     Color  Season  \
# 1211                   94        Oklahoma    M     Green  Spring
# 350                    68        Kentucky    M    Violet  Spring
# 2845                   77    South Dakota    L  Lavender  Summer
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Customer_ID  Age  Gender Item_Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase_Amount_USD       Location Size      Color  Season  \
# 0                      53       Kentucky    L       Gray  Winter
# 1                      64          Maine    L     Maroon  Winter
# ...

# %%
df.nunique()
# Out:
# Customer_ID                 3900
# Age                           53
# Gender                         2
# Item_Purchased                25
# Category                       4
# Purchase_Amount_USD           81
# Location                      50
# Size                           4
# Color                         25
# Season                         4
# Review_Rating                 26
# Subscription_Status            2
# Payment_Method                 6
# Shipping_Type                  6
# Discount_Applied               2
# Promo_Code_Used                2
# Previous_Purchases            50
# Preferred_Payment_Method       6
# Frequency_of_Purchases         7
# dtype: int64

# %%
missing_mask = df.isnull().any(axis=1)

# %%
num_missing_rows = missing_mask.sum()
print(f"Number of rows with missing values: {num_missing_rows}")
# Out:
# Number of rows with missing values: 0

# %%
gender_count=df['Gender'].value_counts()
gender_count
# Out:
# Gender
# Male      2652
# Female    1248
# Name: count, dtype: int64

# %%
explode=(0,0.05)
plt.pie(gender_count,labels=gender_count.index,explode=explode,autopct='%1.1f%%')
plt.axis('equal')
plt.legend(labels=gender_count.index,loc="best")
plt.show()

# %%
items_count=df['Item_Purchased'].value_counts()
items_count
# Out:
# Item_Purchased
# Blouse        171
# Pants         171
# Jewelry       171
# Shirt         169
# Dress         166
# Sweater       164
# Jacket        163
# Coat          161
# Sunglasses    161
# Belt          161
# Sandals       160
# Socks         159
# Skirt         158
# Scarf         157
# Shorts        157
# Hat           154
# Handbag       153
# Hoodie        151
# Shoes         150
# T-shirt       147
# Sneakers      145
# Boots         144
# Backpack      143
# Gloves        140
# Jeans         124
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
items_count.plot(kind='barh',x='count of the item',color=colors,y='item',legend=False)
plt.xlabel('count for every item')
plt.ylabel('item')
plt.tight_layout()
plt.show()

# %%
cat_count=df['Category'].value_counts()
cat_count
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,7))
explode=(0,0.02,0.04,0.06)
plt.pie(cat_count,colors=colors,labels=cat_count.index,explode=explode,autopct='%1.1f%%')
plt.axis('equal')
plt.legend(labels=cat_count.index,loc='best')
plt.show()

# %%
loc_count=df['Location'].value_counts()
loc_count
# Out:
# Location
# Montana           96
# California        95
# Idaho             93
# Illinois          92
# Alabama           89
# Minnesota         88
# New York          87
# Nevada            87
# Nebraska          87
# Delaware          86
# Maryland          86
# Vermont           85
# Louisiana         84
# North Dakota      83
# West Virginia     81
# Missouri          81
# New Mexico        81
# Mississippi       80
# Kentucky          79
# Arkansas          79
# Georgia           79
# Indiana           79
# Connecticut       78
# North Carolina    78
# Maine             77
# Ohio              77
# Virginia          77
# Texas             77
# Tennessee         77
# South Carolina    76
# Oklahoma          75
# Wisconsin         75
# Colorado          75
# Oregon            74
# Pennsylvania      74
# Michigan          73
# Washington        73
# Alaska            72
# Massachusetts     72
# Utah              71
# Wyoming           71
# New Hampshire     71
# South Dakota      70
# ...

# %%
# !pip install plotly
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\dg038\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

# %%
fig = px.bar(df['Location'], title="Interactive Bar Chart")
fig.update_layout(xaxis_tickangle=-45, height=600)
fig.show()

# %%
size_count=df['Size'].value_counts()
size_count
# Out:
# Size
# M     1755
# L     1053
# S      663
# XL     429
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,7))
size_count.plot(kind='bar',x='size',y='count',color=colors)
plt.xlabel('size')
plt.ylabel('count')
plt.show()

# %%
df['Color'].value_counts()
# Out:
# Color
# Olive        177
# Yellow       174
# Silver       173
# Teal         172
# Green        169
# Black        167
# Cyan         166
# Violet       166
# Gray         159
# Maroon       158
# Orange       154
# Charcoal     153
# Pink         153
# Blue         152
# Magenta      152
# Purple       151
# Peach        149
# Red          148
# Beige        147
# Indigo       147
# Lavender     147
# Turquoise    145
# White        142
# Brown        141
# Gold         138
# Name: count, dtype: int64

# %%
fig = px.bar(df['Color'], title="Color's Bar Chart")
fig.update_layout(xaxis_tickangle=-30, height=600)
fig.show()

# %%
season_count=df['Season'].value_counts()
season_count
# Out:
# Season
# Spring    999
# Fall      975
# Winter    971
# Summer    955
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,5))
ax=season_count.plot(kind='bar',color=colors)
for i, count in enumerate(season_count):
    ax.text(i, count + 0.1, str(count), ha='center', va='bottom', fontsize=10)


plt.show()

# %%
sub_count=df['Subscription_Status'].value_counts()
sub_count
# Out:
# Subscription_Status
# No     2847
# Yes    1053
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
explode=(0,0.1)
plt.pie(sub_count,labels=sub_count.index,colors=colors,explode=explode,autopct='%1.1f%%')
plt.legend(labels=sub_count.index,loc='best')
plt.show()

# %%
payment_c=df['Payment_Method'].value_counts()
payment_c
# Out:
# Payment_Method
# Credit Card      696
# Venmo            653
# Cash             648
# PayPal           638
# Debit Card       633
# Bank Transfer    632
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.pie(payment_c,labels=payment_c.index,colors=colors,autopct='%1.1f%%')
plt.axis('equal')  
plt.legend(labels=payment_c.index,loc='best')
plt.show()

# %%
sub_status_c=df['Subscription_Status'].value_counts()
sub_status_c
# Out:
# Subscription_Status
# No     2847
# Yes    1053
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.bar(sub_status_c.index, sub_status_c.values, color=colors)
for i,count in enumerate(sub_status_c):
    plt.text(i, count + 0.1, str(count), ha='center', va='bottom', fontsize=12)
plt.xlabel('Subscription Status')
plt.ylabel('Count') 
plt.show()

# %%
shipping_c=df['Shipping_Type'].value_counts()
shipping_c
# Out:
# Shipping_Type
# Free Shipping     675
# Standard          654
# Store Pickup      650
# Next Day Air      648
# Express           646
# 2-Day Shipping    627
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
shipping_c.plot(kind='barh',x='Shipping Type',y='count',color=colors)
plt.xlabel('count for every shipping type')
plt.ylabel('Shipping Type')
for i, count in enumerate(shipping_c):
    plt.text(count + 0.1, i, str(count), ha='left', va='center', fontsize=12)
plt.show()

# %%
freq_count=df['Frequency_of_Purchases'].value_counts()
freq_count
# Out:
# Frequency_of_Purchases
# Every 3 Months    584
# Annually          572
# Quarterly         563
# Monthly           553
# Bi-Weekly         547
# Fortnightly       542
# Weekly            539
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
freq_count.plot(kind='bar',color=colors)
for i, count in enumerate(freq_count):
    plt.text(i, count + 0.1, str(count), ha='center', va='bottom', fontsize=12)
plt.xlabel('Frequency of Purchases')
plt.ylabel('Count') 
plt.show()

# %%
df.describe()
# Out:
#        Customer_ID          Age  Purchase_Amount_USD  Review_Rating  \
# count  3900.000000  3900.000000          3900.000000    3900.000000
# mean   1950.500000    44.068462            59.764359       3.749949
# std    1125.977353    15.207589            23.685392       0.716223
# min       1.000000    18.000000            20.000000       2.500000
# 25%     975.750000    31.000000            39.000000       3.100000
# 50%    1950.500000    44.000000            60.000000       3.700000
# 75%    2925.250000    57.000000            81.000000       4.400000
# max    3900.000000    70.000000           100.000000       5.000000
#
#        Previous_Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
most_comm_item=df['Item_Purchased'].mode()[0]
most_comm_item
# Out:
# 'Blouse'

# %%
most_comm_payment=df['Payment_Method'].mode()[0]
print('the most common payment method is:', most_comm_payment)
print(f"The most common item purchased is: {most_comm_item} with the payment method: {most_comm_payment}")
# Out:
# the most common payment method is: Credit Card
# The most common item purchased is: Blouse with the payment method: Credit Card

# %%
most_cat=df['Category'].mode()[0]
print(f"The most common item purchased is: {most_comm_item} in the category: {most_cat}")
# Out:
# The most common item purchased is: Blouse in the category: Clothing

# %%
most_location=df['Location'].mode()[0]
print(f"The most common location is: {most_location}")
# Out:
# The most common location is: Montana

# %%
most_season=df['Season'].mode()[0]
print(f"The most common season is: {most_season}")
# Out:
# The most common season is: Spring

# %%
total_purchases_by_cat=df.groupby('Category')['Purchase_Amount_USD'].sum()
print("the total purchse amount by category is:")
total_purchases_by_cat
# Out:
# the total purchse amount by category is:
# Category
# Accessories     74200
# Clothing       104264
# Footwear        36093
# Outerwear       18524
# Name: Purchase_Amount_USD, dtype: int64

# %%
group=df.groupby('Gender')['Review_Rating'].mean()
print("the average review rating is:")
group
# Out:
# the average review rating is:
# Gender
# Female    3.741426
# Male      3.753959
# Name: Review_Rating, dtype: float64

# %%
madian_Purchase_Amount_USD=df['Purchase_Amount_USD'].median()
print(f"The median purchase amount in USD is: {madian_Purchase_Amount_USD}")
# Out:
# The median purchase amount in USD is: 60.0

# %%
madian_Review_Rating=df['Review_Rating'].median()
print(f"The median review rating is: {madian_Review_Rating}")
# Out:
# The median review rating is: 3.700000047683716

# %%
df.groupby('Gender')['Payment_Method'].value_counts()
# Out:
# Gender  Payment_Method
# Female  Credit Card       223
#         Venmo             214
#         Debit Card        207
#         Bank Transfer     204
#         PayPal            203
#         Cash              197
# Male    Credit Card       473
#         Cash              451
#         Venmo             439
#         PayPal            435
#         Bank Transfer     428
#         Debit Card        426
# Name: count, dtype: int64

# %%
group=df.groupby('Payment_Method')['Purchase_Amount_USD']

# %%
group.value_counts()
# Out:
# Payment_Method  Purchase_Amount_USD
# Bank Transfer   23                     15
#                 64                     15
#                 22                     14
#                 25                     13
#                 96                     13
#                                        ..
# Venmo           43                      4
#                 69                      4
#                 77                      4
#                 87                      4
#                 100                     3
# Name: count, Length: 486, dtype: int64

# %%
df.groupby('Category')["Season"].value_counts()
# Out:
# Category     Season
# Accessories  Fall      324
#              Summer    312
#              Winter    303
#              Spring    301
# Clothing     Spring    454
#              Winter    448
#              Fall      427
#              Summer    408
# Footwear     Spring    163
#              Summer    160
#              Winter    140
#              Fall      136
# Outerwear    Fall       88
#              Spring     81
#              Winter     80
#              Summer     75
# Name: count, dtype: int64

# %%
gp=df.groupby('Gender')['Purchase_Amount_USD']

# %%
gp.describe()
# Out:
#          count       mean        std   min   25%   50%   75%    max
# Gender
# Female  1248.0  60.249199  23.420556  20.0  40.0  60.0  81.0  100.0
# Male    2652.0  59.536199  23.809976  20.0  38.0  60.0  80.0  100.0

# %%
avg_purchase_subscription_yes=df[df['Subscription_Status'] == 'Yes']['Purchase_Amount_USD'].mean()
avg_purchase_subscription_no=df[df['Subscription_Status'] == 'No']['Purchase_Amount_USD'].mean()
print(f"The average purchase amount for subscribers is: {avg_purchase_subscription_yes}")   
print(f"The average purchase amount for non-subscribers is: {avg_purchase_subscription_no}")
# Out:
# The average purchase amount for subscribers is: 59.49192782526116
# The average purchase amount for non-subscribers is: 59.865121180189675

# %%
the_most_comm_seaason=df["Season"].mode()[0]
print('the moset common seson is:', the_most_comm_seaason)
# Out:
# the moset common seson is: Spring

# %%
avg_age_for_purchase_in_summer=df[df['Season']=='Summer']['Age'].mean()
print("The average purchase amount by age in summer is:", avg_age_for_purchase_in_summer)
# Out:
# The average purchase amount by age in summer is: 43.973821989528794

# %%
most_comm_payment_method_in_summer=df[df['Season']=='Summer']['Payment_Method'].mode()[0]
print("The most common payment method in summer is:", most_comm_payment_method_in_summer)
# Out:
# The most common payment method in summer is: Venmo

# %%
most_comm_item_in_summer=df[df['Season']=='Summer']['Item_Purchased'].mode()[0]
print("The most common item purchased in summer is:", most_comm_item_in_summer)
# Out:
# The most common item purchased in summer is: Pants

# %%
most_comm_item_in_winter=df[df['Season']=='Winter']['Item_Purchased'].mode()[0]
print("The most common item purchased in winter is:", most_comm_item_in_winter)
# Out:
# The most common item purchased in winter is: Sunglasses

# %%
group=df.groupby('Season')['Item_Purchased'].value_counts()
print("The purchase items by season is:")
group
# Out:
# The purchase items by season is:
# Season  Item_Purchased
# Fall    Jacket            54
#         Hat               50
#         Handbag           48
#         Skirt             46
#         Sandals           44
#                           ..
# Winter  Gloves            32
#         Sandals           32
#         Boots             31
#         Jeans             29
#         Backpack          25
# Name: count, Length: 100, dtype: int64

# %%
df.sample(10)
# Out:
#       Customer_ID  Age  Gender Item_Purchased     Category  \
# 3806         3807   18  Female          Boots     Footwear
# 3615         3616   35  Female          Dress     Clothing
# 318           319   45    Male       Backpack  Accessories
# 79             80   38    Male         Jacket    Outerwear
# 3645         3646   38  Female       Backpack  Accessories
# 97             98   21    Male          Shoes     Footwear
# 2363         2364   60    Male          Socks     Clothing
# 1685         1686   33    Male         Blouse     Clothing
# 3060         3061   47  Female           Coat    Outerwear
# 3435         3436   68  Female          Socks     Clothing
#
#       Purchase_Amount_USD      Location Size     Color  Season  Review_Rating  \
# 3806                   71      Missouri    M      Teal  Spring            3.0
# 3615                   31    California    M      Gold  Winter            4.4
# 318                    67  South Dakota    M     Beige  Winter            2.5
# ...

# %%
group=df.groupby('Discount_Applied')['Promo_Code_Used'].value_counts()
print("The promo codes used by discount applied is:")
group
# Out:
# The promo codes used by discount applied is:
# Discount_Applied  Promo_Code_Used
# No                No                 2223
# Yes               Yes                1677
# Name: count, dtype: int64

# %%
customers_use_promocodes=df[df['Promo_Code_Used']=='Yes']["Customer_ID"].count()
print("The promo codes used by customers",customers_use_promocodes)
# Out:
# The promo codes used by customers 1677

# %%
customers_use_promocodes=df[df['Promo_Code_Used']=='No']["Customer_ID"].count()
print("The promo codes used by customers",customers_use_promocodes)
# Out:
# The promo codes used by customers 2223

# %%
min_rev_rate=df['Review_Rating'].min()
print(f"The minimum review rating is: {min_rev_rate}")
# Out:
# The minimum review rating is: 2.5

# %%
max_rev_rate=df['Review_Rating'].max()
print(f"The maximum review rating is: {max_rev_rate}")
# Out:
# The maximum review rating is: 5.0

# %%
group=df.groupby('Shipping_Type')["Payment_Method"].value_counts()
print("The payment methods by shipping type is:")
group
# Out:
# The payment methods by shipping type is:
# Shipping_Type   Payment_Method
# 2-Day Shipping  Venmo             115
#                 Cash              108
#                 Debit Card        107
#                 PayPal            104
#                 Bank Transfer     101
#                 Credit Card        92
# Express         Venmo             118
#                 Credit Card       116
#                 Bank Transfer     109
#                 Debit Card        107
#                 Cash              102
#                 PayPal             94
# Free Shipping   Credit Card       126
#                 Cash              119
#                 PayPal            116
#                 Debit Card        109
#                 Venmo             104
#                 Bank Transfer     101
# Next Day Air    PayPal            120
#                 Venmo             116
#                 Credit Card       108
#                 Bank Transfer     102
#                 Cash              101
# ...

# %%
customers_with_purchases_morethan50=df[df['Previous_Purchases'] > 50]["Customer_ID"].count()
print(f"The number of customers with more than 50 purchases is: {customers_with_purchases_morethan50}")
# Out:
# The number of customers with more than 50 purchases is: 0

# %%
customers_with_purchases_morethan40=df[df['Previous_Purchases'] > 40]["Customer_ID"].count()
print(f"The number of customers with more than 50 purchases is: {customers_with_purchases_morethan40}")
# Out:
# The number of customers with more than 50 purchases is: 765

# %%
customers_with_purchases_lessthan40=df[df['Previous_Purchases'] < 40]["Customer_ID"].count()
print(f"The number of customers with more than 50 purchases is: {customers_with_purchases_lessthan40}")
# Out:
# The number of customers with more than 50 purchases is: 3053

# %%
pd.crosstab(df['Discount_Applied'], df['Promo_Code_Used'], margins=True, margins_name="Total")
# Out:
# Promo_Code_Used     No   Yes  Total
# Discount_Applied
# No                2223     0   2223
# Yes                  0  1677   1677
# Total             2223  1677   3900

# %%
avg_purchase_with_discount=df[df['Discount_Applied'] == 'Yes']['Purchase_Amount_USD'].mean()
avg_purchase_without_discount=df[df['Discount_Applied'] == 'No']['Purchase_Amount_USD'].mean()
print(f"The average purchase amount with discount is: {avg_purchase_with_discount}")    
print(f"The average purchase amount without discount is: {avg_purchase_without_discount}")
# Out:
# The average purchase amount with discount is: 59.27906976744186
# The average purchase amount without discount is: 60.130454340980656

# %%
comm_category_with_low_rating_doneby_female=df[(df['Review_Rating'] < 3) &(df['Gender']=='Female')]['Category'].mode()[0]
print(f"The most common category with low rating done by female is: {comm_category_with_low_rating_doneby_female}")
# Out:
# The most common category with low rating done by female is: Clothing

# %%
comm_category_with_high_rating_doneby_male=df[(df['Review_Rating'] > 4)& (df['Gender']=='Male')]['Category'].mode()[0]
print('the most common category with high rating', comm_category_with_high_rating_doneby_male)
# Out:
# the most common category with high rating Clothing

# %%
group_of_colors=df.groupby('Color')['Purchase_Amount_USD']
print("The purchase amount by color is:")
group_of_colors.value_counts()
# Out:
# The purchase amount by color is:
# Color   Purchase_Amount_USD
# Beige   90                     6
#         23                     5
#         29                     4
#         46                     4
#         59                     4
#                               ..
# Yellow  71                     1
#         77                     1
#         80                     1
#         84                     1
#         86                     1
# Name: count, Length: 1721, dtype: int64

# %%
group_of_colors.mean()
# Out:
# Color
# Beige        60.414966
# Black        58.401198
# Blue         56.953947
# Brown        59.063830
# Charcoal     60.633987
# Cyan         61.891566
# Gold         61.007246
# Gray         62.490566
# Green        65.704142
# Indigo       56.251701
# Lavender     59.129252
# Magenta      57.131579
# Maroon       59.525316
# Olive        58.146893
# Orange       60.889610
# Peach        59.187919
# Pink         60.588235
# Purple       60.013245
# Red          59.317568
# Silver       56.832370
# Teal         60.808140
# Turquoise    55.613793
# Violet       61.716867
# White        62.640845
# Yellow       59.241379
# Name: Purchase_Amount_USD, dtype: float64

# %%
group_of_colors.max()
# Out:
# Color
# Beige        100
# Black        100
# Blue         100
# Brown         98
# Charcoal     100
# Cyan         100
# Gold         100
# Gray          99
# Green        100
# Indigo        99
# Lavender      99
# Magenta       99
# Maroon        99
# Olive        100
# Orange        99
# Peach        100
# Pink         100
# Purple        99
# Red          100
# Silver       100
# Teal          99
# Turquoise    100
# Violet        99
# White        100
# Yellow       100
# Name: Purchase_Amount_USD, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()
df['Color_Encoded'] = encoder.fit_transform(df[['Color']])

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()
df['Size'] = encoder.fit_transform(df[['Size']])

# %%
sns.boxenplot(x=df['Size'],y=df['Age'])
plt.title("Box plot of Age by Size")
plt.show()

# %%
plt.Figure(figsize=(20,15))
plt.bar(df['Age'],df['Review_Rating'])
plt.xlabel('Age')
plt.ylabel('Review Rating')
plt.title('Bar Chart of Review Rating by Age')
plt.show()

# %%
sns.scatterplot(x=df['Age'], y=df['Review_Rating'])
plt.title("Scatter Plot of Review Rating by Age")
plt.xlabel('Age')
plt.ylabel('Review Rating')
plt.show()

# %%
pd.crosstab(df['Gender'],df['Item_Purchased'])
# Out:
# Item_Purchased  Backpack  Belt  Blouse  Boots  Coat  Dress  Gloves  Handbag  \
# Gender
# Female                37    55      66     50    47     52      37       58
# Male                 106   106     105     94   114    114     103       95
#
# Item_Purchased  Hat  Hoodie  ...  Scarf  Shirt  Shoes  Shorts  Skirt  \
# Gender                       ...
# Female           52      51  ...     45     59     48      48     49
# Male            102     100  ...    112    110    102     109    109
#
# Item_Purchased  Sneakers  Socks  Sunglasses  Sweater  T-shirt
# Gender
# Female                42     58          56       50       46
# Male                 103    101         105      114      101
#
# [2 rows x 25 columns]

# %%
pd.crosstab(df['Gender'],df['Size'])
# Out:
# Size    0.0   1.0  2.0  3.0
# Gender
# Female  337   590  187  134
# Male    716  1165  476  295

# %%
sns.scatterplot(x=df['Season'],y=df['Color'])
# Out:
# <Axes: xlabel='Season', ylabel='Color'>

# %%
plt.figure(figsize=(10,7))
plt.hist(df['Age'], bins=20,edgecolor='BLACK')
plt.title('Histogram of Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
